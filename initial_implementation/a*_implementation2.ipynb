# %%
import cv2
import numpy as np
from PIL import Image
import queue
import matplotlib.pyplot as plt
from heapq import heappop, heappush
import math

# %%
class Vertex:
    def __init__(self,x_coordinate,y_coordinate):
        self.x = x_coordinate
        self.y = y_coordinate
        self.xParent = None
        self.yParent = None
        self.processed = False
        self.queueIndex = None
        self.condition = None

# %%
def get_neighbors(mat, r, c):
    shape=mat.shape
    neighbors=[]
    #ensure neighbors are within image boundaries
    if r > 0 and not mat[r-1][c].processed and not mat[r-1][c].condition ==0:
        neighbors.append(mat[r-1][c])
    if r < shape[0] - 1 and not mat[r+1][c].processed and not mat[r+1][c].condition ==0:
        neighbors.append(mat[r+1][c])
    if c > 0 and not mat[r][c-1].processed and not mat[r][c-1].condition ==0:
        neighbors.append(mat[r][c-1])
    if c < shape[1] - 1 and not mat[r][c+1].processed and not mat[r][c+1].condition == 0:
        neighbors.append(mat[r][c+1])
    return neighbors

# %%
def path_from(matrix, x, y, xS, yS):
    path = []
    iter_v=matrix[y][x]
    path.append((x,y))
    while(iter_v.y!=yS or iter_v.x!=xS):
        path.append((iter_v.x,iter_v.y))
        iter_v=matrix[iter_v.yParent][iter_v.xParent]
    path.append((xS,yS))
    return path

# %%
def heuristic(cell, goal):
    #return abs(cell[0] - goal[0]) + abs(cell[1] - goal[1])
    return math.sqrt(abs(cell[0] - goal[0])**2 + abs(cell[1] - goal[1])**2)

# %%
def find_shortest_path_astar(matrix, x_start, y_start, x_end, y_end):
    #assuming start and end are withing bounds
    #let 0 be black (can't visit)
    #let 1 be white (can visit)
    lenrows, lencols = matrix.shape
    print('rows', lenrows)
    print('cols', lencols)
    vectorMatrix = np.full((lenrows, lencols), None)
    for r in range(lenrows):
        for c in range(lencols):
            #print(matrix[0][0])
            vectorMatrix[r][c] = Vertex(c, r)
            vectorMatrix[r][c].condition = matrix[r][c]
    #vectorMatrix[y_start][x_start].condition = -1
    vectorMatrix[y_end][x_end].condition = -2
    
    #changes for a*
    start = (x_start, y_start)
    goal = (x_end, y_end)
    pr_queue = []
    #path = []
    #path.append(start)
    heappush(pr_queue, (0 + heuristic(start, goal), 0, "", start))
    visited = set()
    while pr_queue:
        _, cost, path, current = heappop(pr_queue)
        print('currently on node: ' + str(current))
        #print('current path: ', path)
        if current == goal:
            print('found')
            return path
        if current in visited:
            continue
        visited.add(current)
        neighbors = get_neighbors(vectorMatrix, current[0], current[1])
        for neighbor in neighbors:
            #print('neighbor: '+ str(neighbor.x) + ' , ' + str(neighbor.y))
            heappush(pr_queue, (cost + heuristic((neighbor.x, neighbor.y), goal), cost+1, path + str((neighbor.x, neighbor.y)) + ',', (neighbor.x, neighbor.y)))
    
    return "no way"

# %%
def draw_path(img,path, thickness=2):
    '''path is a list of (x,y) tuples'''
    print('drawing path')
    x0,y0=path[0]
    for vertex in path[1:]:
        #print(vertex)
        x1,y1=vertex
        cv2.line(img,(x0,y0),(x1,y1),(0,0,255),thickness)
        x0,y0=vertex

# %%
def cv2_to_PIL(image):
    return Image.fromarray(image)

# %%
def solve_maze_astar(image: str, x_start, y_start, x_end, y_end):
    image_array = cv2.imread(image, 0)
    ret,thresh1 = cv2.threshold(image_array,127,255,cv2.THRESH_BINARY)
    return find_shortest_path_astar(thresh1, x_start, y_start, x_end, y_end)
#     image_array_color = cv2.imread(image,1)
#     draw_path(image_array_color, find_shortest_path_bfs(thresh1, x_start, y_start, x_end, y_end), 6)
#     cv2.circle(image_array_color, (x_start, y_start), 5, (0,200,40), -1)
#     cv2.circle(image_array_color, (x_end, y_end), 5, (255,0,0), -1)
#     return cv2_to_PIL(image_array_color)

# %%
def solve_maze_bfs(image: str, x_start, y_start, x_end, y_end):
    image_array = cv2.imread(image, 0)
    ret,thresh1 = cv2.threshold(image_array,127,255,cv2.THRESH_BINARY)
    image_array_color = cv2.imread(image,1)
    draw_path(image_array_color, find_shortest_path_bfs(thresh1, x_start, y_start, x_end, y_end), 6)
    cv2.circle(image_array_color, (x_start, y_start), 5, (0,200,40), -1)
    cv2.circle(image_array_color, (x_end, y_end), 5, (255,0,0), -1)
    return cv2_to_PIL(image_array_color)

# %%
path = solve_maze_astar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-0cb926bfedc4> in <module>
# ----> 1 path = solve_maze_astar()
#
# TypeError: solve_maze_astar() missing 5 required positional arguments: 'image', 'x_start', 'y_start', 'x_end', and 'y_end'

# %%
solve = solve_maze_astar('maze_images/simple_maze2.png', 25, 25, 367,250)
solve
# Out:
# rows 253
# cols 389
# currently on node: (25, 25)
# currently on node: (26, 25)
# currently on node: (25, 26)
# currently on node: (27, 25)
# currently on node: (26, 26)
# currently on node: (26, 26)
# currently on node: (27, 26)
# currently on node: (25, 27)
# currently on node: (28, 25)
# currently on node: (27, 26)
# currently on node: (26, 27)
# currently on node: (28, 26)
# currently on node: (26, 27)
# currently on node: (27, 27)
# currently on node: (27, 27)
# currently on node: (25, 28)
# currently on node: (29, 25)
# currently on node: (28, 26)
# currently on node: (28, 27)
# currently on node: (26, 28)
# currently on node: (29, 26)
# currently on node: (28, 27)
# currently on node: (26, 28)
# currently on node: (25, 24)
# currently on node: (27, 28)
# currently on node: (29, 27)
# currently on node: (27, 28)
# currently on node: (26, 24)
# currently on node: (25, 29)
# currently on node: (30, 25)
# currently on node: (29, 26)
# currently on node: (24, 25)
# currently on node: (26, 24)
# currently on node: (28, 28)
# currently on node: (28, 28)
# currently on node: (27, 24)
# currently on node: (26, 29)
# currently on node: (30, 26)
# currently on node: (29, 27)
# currently on node: (26, 29)
# currently on node: (25, 25)
# currently on node: (25, 25)
# currently on node: (25, 25)
# currently on node: (25, 25)
# currently on node: (29, 28)
# currently on node: (28, 24)
# currently on node: (27, 29)
# currently on node: (30, 27)
# currently on node: (29, 28)
# currently on node: (27, 29)
# currently on node: (26, 25)
# currently on node: (26, 25)
# currently on node: (29, 24)
# currently on node: (25, 30)
# currently on node: (31, 25)
# currently on node: (30, 26)
# currently on node: (24, 26)
# currently on node: (27, 24)
# currently on node: (26, 25)
# currently on node: (24, 26)
# currently on node: (28, 29)
# currently on node: (30, 28)
# currently on node: (28, 29)
# currently on node: (27, 25)
# currently on node: (27, 25)
# currently on node: (30, 24)
# currently on node: (26, 30)
# currently on node: (31, 26)
# currently on node: (30, 27)
# currently on node: (26, 30)
# currently on node: (25, 26)
# currently on node: (25, 26)
# currently on node: (25, 26)
# currently on node: (29, 29)
# currently on node: (29, 29)
# currently on node: (28, 25)
# currently on node: (28, 25)
# currently on node: (27, 30)
# currently on node: (31, 27)
# currently on node: (30, 28)
# currently on node: (27, 30)
# currently on node: (26, 26)
# currently on node: (26, 26)
# currently on node: (30, 29)
# currently on node: (29, 25)
# currently on node: (29, 25)
# currently on node: (25, 31)
# currently on node: (32, 25)
# currently on node: (31, 26)
# currently on node: (31, 24)
# currently on node: (24, 27)
# currently on node: (28, 24)
# currently on node: (27, 25)
# currently on node: (24, 27)
# currently on node: (28, 30)
# currently on node: (31, 28)
# currently on node: (30, 29)
# currently on node: (28, 30)
# currently on node: (27, 26)
# currently on node: (27, 26)
# currently on node: (30, 25)
# currently on node: (30, 25)
# currently on node: (26, 31)
# currently on node: (32, 26)
# currently on node: (31, 27)
# currently on node: (26, 31)
# currently on node: (25, 27)
# currently on node: (25, 27)
# currently on node: (25, 27)
# currently on node: (29, 30)
# currently on node: (31, 29)
# currently on node: (29, 30)
# currently on node: (28, 26)
# currently on node: (28, 26)
# currently on node: (31, 25)
# currently on node: (27, 31)
# currently on node: (32, 27)
# currently on node: (31, 28)
# currently on node: (27, 31)
# currently on node: (26, 27)
# currently on node: (26, 27)
# currently on node: (30, 30)
# currently on node: (30, 30)
# currently on node: (25, 23)
# currently on node: (29, 26)
# currently on node: (29, 26)
# currently on node: (25, 32)
# currently on node: (33, 25)
# currently on node: (32, 26)
# currently on node: (32, 24)
# currently on node: (31, 25)
# currently on node: (24, 28)
# currently on node: (29, 24)
# currently on node: (28, 25)
# currently on node: (24, 28)
# currently on node: (28, 31)
# currently on node: (32, 28)
# currently on node: (31, 29)
# currently on node: (28, 31)
# currently on node: (27, 27)
# currently on node: (27, 27)
# currently on node: (31, 30)
# currently on node: (26, 23)
# currently on node: (30, 26)
# currently on node: (30, 26)
# currently on node: (26, 32)
# currently on node: (33, 26)
# currently on node: (32, 27)
# currently on node: (32, 25)
# currently on node: (26, 32)
# currently on node: (25, 28)
# currently on node: (25, 28)
# currently on node: (25, 28)
# currently on node: (29, 31)
# currently on node: (32, 29)
# currently on node: (31, 30)
# currently on node: (29, 31)
# currently on node: (24, 24)
# currently on node: (24, 24)
# currently on node: (28, 27)
# currently on node: (28, 27)
# currently on node: (27, 23)
# currently on node: (31, 26)
# currently on node: (31, 26)
# currently on node: (27, 32)
# currently on node: (33, 27)
# currently on node: (32, 28)
# currently on node: (27, 32)
# currently on node: (26, 28)
# currently on node: (26, 28)
# currently on node: (30, 31)
# currently on node: (32, 30)
# currently on node: (30, 31)
# currently on node: (25, 24)
# currently on node: (25, 24)
# currently on node: (29, 27)
# currently on node: (29, 27)
# currently on node: (28, 23)
# currently on node: (32, 26)
# currently on node: (24, 29)
# currently on node: (30, 24)
# currently on node: (29, 25)
# currently on node: (24, 29)
# currently on node: (25, 33)
# currently on node: (34, 25)
# currently on node: (33, 26)
# currently on node: (33, 24)
# currently on node: (32, 25)
# currently on node: (28, 32)
# currently on node: (33, 28)
# currently on node: (32, 29)
# currently on node: (28, 32)
# currently on node: (23, 25)
# currently on node: (26, 23)
# currently on node: (25, 24)
# currently on node: (27, 28)
# currently on node: (27, 28)
# currently on node: (31, 31)
# currently on node: (31, 31)
# currently on node: (26, 24)
# currently on node: (30, 27)
# currently on node: (30, 27)
# currently on node: (29, 23)
# currently on node: (26, 33)
# currently on node: (34, 26)
# currently on node: (33, 27)
# currently on node: (33, 25)
# currently on node: (32, 26)
# currently on node: (26, 33)
# currently on node: (25, 29)
# currently on node: (25, 29)
# currently on node: (25, 29)
# currently on node: (29, 32)
# currently on node: (33, 29)
# currently on node: (32, 30)
# currently on node: (29, 32)
# currently on node: (24, 25)
# currently on node: (24, 25)
# currently on node: (24, 25)
# currently on node: (28, 28)
# currently on node: (28, 28)
# currently on node: (32, 31)
# currently on node: (27, 24)
# currently on node: (31, 27)
# currently on node: (31, 27)
# currently on node: (27, 33)
# currently on node: (34, 27)
# currently on node: (33, 28)
# currently on node: (33, 26)
# currently on node: (27, 33)
# currently on node: (26, 29)
# currently on node: (26, 29)
# currently on node: (30, 32)
# currently on node: (33, 30)
# currently on node: (32, 31)
# currently on node: (30, 32)
# currently on node: (29, 28)
# currently on node: (29, 28)
# currently on node: (28, 24)
# currently on node: (32, 27)
# currently on node: (32, 27)
# currently on node: (24, 30)
# currently on node: (31, 24)
# currently on node: (30, 25)
# currently on node: (30, 23)
# currently on node: (24, 30)
# currently on node: (25, 34)
# currently on node: (35, 25)
# currently on node: (34, 26)
# currently on node: (34, 24)
# currently on node: (33, 25)
# currently on node: (23, 26)
# currently on node: (27, 23)
# currently on node: (26, 24)
# currently on node: (23, 26)
# currently on node: (28, 33)
# currently on node: (34, 28)
# currently on node: (33, 29)
# currently on node: (28, 33)
# currently on node: (27, 29)
# currently on node: (27, 29)
# currently on node: (31, 32)
# currently on node: (33, 31)
# currently on node: (31, 32)
# currently on node: (30, 28)
# currently on node: (30, 28)
# currently on node: (29, 24)
# currently on node: (33, 27)
# currently on node: (25, 30)
# currently on node: (25, 30)
# currently on node: (25, 30)
# currently on node: (26, 34)
# currently on node: (35, 26)
# currently on node: (34, 27)
# currently on node: (34, 25)
# currently on node: (33, 26)
# currently on node: (26, 34)
# currently on node: (29, 33)
# currently on node: (34, 29)
# currently on node: (33, 30)
# currently on node: (29, 33)
# currently on node: (24, 26)
# currently on node: (24, 26)
# currently on node: (28, 29)
# currently on node: (28, 29)
# currently on node: (32, 32)
# currently on node: (32, 32)
# currently on node: (31, 28)
# currently on node: (31, 28)
# currently on node: (26, 30)
# currently on node: (26, 30)
# currently on node: (27, 34)
# currently on node: (35, 27)
# currently on node: (34, 28)
# currently on node: (34, 26)
# currently on node: (33, 27)
# currently on node: (27, 34)
# currently on node: (30, 33)
# currently on node: (34, 30)
# currently on node: (33, 31)
# currently on node: (30, 33)
# currently on node: (29, 29)
# currently on node: (29, 29)
# currently on node: (33, 32)
# currently on node: (32, 28)
# currently on node: (32, 28)
# currently on node: (24, 31)
# currently on node: (32, 24)
# currently on node: (31, 25)
# currently on node: (31, 23)
# currently on node: (30, 24)
# currently on node: (24, 31)
# currently on node: (23, 27)
# currently on node: (28, 23)
# currently on node: (27, 24)
# currently on node: (23, 27)
# currently on node: (28, 34)
# currently on node: (35, 28)
# currently on node: (34, 29)
# currently on node: (34, 27)
# currently on node: (28, 34)
# currently on node: (25, 35)
# currently on node: (36, 25)
# currently on node: (35, 26)
# currently on node: (35, 24)
# currently on node: (34, 25)
# currently on node: (27, 30)
# currently on node: (27, 30)
# currently on node: (31, 33)
# currently on node: (34, 31)
# currently on node: (33, 32)
# currently on node: (31, 33)
# currently on node: (30, 29)
# currently on node: (30, 29)
# currently on node: (25, 22)
# currently on node: (33, 28)
# currently on node: (33, 28)
# currently on node: (25, 31)
# currently on node: (25, 31)
# currently on node: (25, 31)
# currently on node: (24, 27)
# currently on node: (24, 27)
# currently on node: (26, 35)
# currently on node: (36, 26)
# currently on node: (35, 27)
# currently on node: (35, 25)
# currently on node: (34, 26)
# currently on node: (26, 35)
# currently on node: (29, 34)
# currently on node: (35, 29)
# currently on node: (34, 30)
# currently on node: (29, 34)
# currently on node: (28, 30)
# currently on node: (28, 30)
# currently on node: (32, 33)
# currently on node: (34, 32)
# currently on node: (32, 33)
# currently on node: (31, 29)
# currently on node: (31, 29)
# currently on node: (26, 22)
# currently on node: (34, 28)
# currently on node: (26, 31)
# currently on node: (26, 31)
# currently on node: (27, 35)
# currently on node: (36, 27)
# currently on node: (35, 28)
# currently on node: (35, 26)
# currently on node: (34, 27)
# currently on node: (27, 35)
# currently on node: (30, 34)
# currently on node: (35, 30)
# currently on node: (34, 31)
# currently on node: (30, 34)
# currently on node: (29, 30)
# currently on node: (29, 30)
# currently on node: (33, 33)
# currently on node: (33, 33)
# currently on node: (24, 23)
# currently on node: (24, 23)
# currently on node: (32, 29)
# currently on node: (32, 29)
# currently on node: (27, 22)
# currently on node: (23, 28)
# currently on node: (29, 23)
# currently on node: (28, 24)
# currently on node: (23, 28)
# currently on node: (24, 32)
# currently on node: (33, 24)
# currently on node: (32, 25)
# currently on node: (32, 23)
# currently on node: (31, 24)
# currently on node: (24, 32)
# currently on node: (27, 31)
# currently on node: (27, 31)
# currently on node: (28, 35)
# currently on node: (36, 28)
# currently on node: (35, 29)
# currently on node: (35, 27)
# currently on node: (34, 28)
# currently on node: (28, 35)
# currently on node: (25, 36)
# currently on node: (37, 25)
# currently on node: (36, 26)
# currently on node: (36, 24)
# currently on node: (35, 25)
# currently on node: (31, 34)
# currently on node: (35, 31)
# currently on node: (34, 32)
# currently on node: (31, 34)
# currently on node: (30, 30)
# currently on node: (30, 30)
# currently on node: (34, 33)
# currently on node: (25, 23)
# currently on node: (33, 29)
# currently on node: (33, 29)
# currently on node: (28, 22)
# currently on node: (25, 32)
# currently on node: (25, 32)
# currently on node: (25, 32)
# currently on node: (24, 28)
# currently on node: (24, 28)
# currently on node: (29, 35)
# currently on node: (36, 29)
# currently on node: (35, 30)
# currently on node: (35, 28)
# currently on node: (29, 35)
# currently on node: (28, 31)
# currently on node: (28, 31)
# currently on node: (26, 36)
# currently on node: (37, 26)
# currently on node: (36, 27)
# currently on node: (36, 25)
# currently on node: (35, 26)
# currently on node: (26, 36)
# currently on node: (23, 24)
# currently on node: (25, 23)
# currently on node: (23, 24)
# currently on node: (32, 34)
# currently on node: (35, 32)
# currently on node: (34, 33)
# currently on node: (32, 34)
# currently on node: (31, 30)
# currently on node: (31, 30)
# currently on node: (26, 23)
# currently on node: (34, 29)
# currently on node: (34, 29)
# currently on node: (26, 32)
# currently on node: (26, 32)
# currently on node: (27, 36)
# currently on node: (37, 27)
# currently on node: (36, 28)
# currently on node: (36, 26)
# currently on node: (35, 27)
# currently on node: (27, 36)
# currently on node: (30, 35)
# currently on node: (36, 30)
# currently on node: (35, 31)
# currently on node: (30, 35)
# currently on node: (29, 31)
# currently on node: (29, 31)
# currently on node: (33, 34)
# currently on node: (35, 33)
# currently on node: (33, 34)
# currently on node: (24, 24)
# currently on node: (24, 24)
# currently on node: (32, 30)
# currently on node: (32, 30)
# currently on node: (27, 23)
# currently on node: (35, 29)
# currently on node: (23, 29)
# currently on node: (30, 23)
# currently on node: (29, 24)
# currently on node: (29, 22)
# currently on node: (23, 29)
# currently on node: (24, 33)
# currently on node: (34, 24)
# currently on node: (33, 25)
# currently on node: (33, 23)
# currently on node: (32, 24)
# currently on node: (24, 33)
# currently on node: (22, 25)
# currently on node: (26, 22)
# currently on node: (25, 23)
# currently on node: (27, 32)
# currently on node: (27, 32)
# currently on node: (28, 36)
# currently on node: (37, 28)
# currently on node: (36, 29)
# currently on node: (36, 27)
# currently on node: (35, 28)
# currently on node: (28, 36)
# currently on node: (31, 35)
# currently on node: (36, 31)
# currently on node: (35, 32)
# currently on node: (31, 35)
# currently on node: (25, 37)
# currently on node: (38, 25)
# currently on node: (37, 26)
# currently on node: (37, 24)
# currently on node: (36, 25)
# currently on node: (30, 31)
# currently on node: (30, 31)
# currently on node: (34, 34)
# currently on node: (34, 34)
# currently on node: (33, 30)
# currently on node: (33, 30)
# currently on node: (28, 23)
# currently on node: (24, 29)
# currently on node: (24, 29)
# currently on node: (25, 33)
# currently on node: (25, 33)
# currently on node: (25, 33)
# currently on node: (28, 32)
# currently on node: (28, 32)
# currently on node: (23, 25)
# currently on node: (23, 25)
# currently on node: (23, 25)
# currently on node: (29, 36)
# currently on node: (37, 29)
# currently on node: (36, 30)
# currently on node: (36, 28)
# currently on node: (35, 29)
# currently on node: (29, 36)
# currently on node: (26, 37)
# currently on node: (38, 26)
# currently on node: (37, 27)
# currently on node: (37, 25)
# currently on node: (36, 26)
# currently on node: (26, 37)
# currently on node: (32, 35)
# currently on node: (36, 32)
# currently on node: (35, 33)
# currently on node: (32, 35)
# currently on node: (31, 31)
# currently on node: (31, 31)
# currently on node: (35, 34)
# currently on node: (34, 30)
# currently on node: (34, 30)
# currently on node: (26, 33)
# currently on node: (26, 33)
# currently on node: (29, 32)
# currently on node: (29, 32)
# currently on node: (30, 36)
# currently on node: (37, 30)
# currently on node: (36, 31)
# currently on node: (36, 29)
# currently on node: (30, 36)
# currently on node: (27, 37)
# currently on node: (38, 27)
# currently on node: (37, 28)
# currently on node: (37, 26)
# currently on node: (36, 27)
# currently on node: (27, 37)
# currently on node: (33, 35)
# currently on node: (36, 33)
# currently on node: (35, 34)
# currently on node: (33, 35)
# currently on node: (32, 31)
# currently on node: (32, 31)
# currently on node: (35, 30)
# currently on node: (35, 30)
# currently on node: (23, 30)
# currently on node: (31, 23)
# currently on node: (30, 24)
# currently on node: (30, 22)
# currently on node: (29, 23)
# currently on node: (23, 30)
# currently on node: (22, 26)
# currently on node: (27, 22)
# currently on node: (26, 23)
# currently on node: (22, 26)
# currently on node: (24, 34)
# currently on node: (35, 24)
# currently on node: (34, 25)
# currently on node: (34, 23)
# currently on node: (33, 24)
# currently on node: (24, 34)
# currently on node: (27, 33)
# currently on node: (27, 33)
# currently on node: (31, 36)
# currently on node: (37, 31)
# currently on node: (36, 32)
# currently on node: (31, 36)
# currently on node: (28, 37)
# currently on node: (38, 28)
# currently on node: (37, 29)
# currently on node: (37, 27)
# currently on node: (36, 28)
# currently on node: (28, 37)
# currently on node: (30, 32)
# currently on node: (30, 32)
# currently on node: (34, 35)
# currently on node: (36, 34)
# currently on node: (34, 35)
# currently on node: (25, 38)
# currently on node: (39, 25)
# currently on node: (38, 26)
# currently on node: (38, 24)
# currently on node: (37, 25)
# currently on node: (33, 31)
# currently on node: (33, 31)
# currently on node: (36, 30)
# currently on node: (24, 30)
# currently on node: (24, 30)
# currently on node: (25, 34)
# currently on node: (25, 34)
# currently on node: (25, 34)
# currently on node: (23, 26)
# currently on node: (23, 26)
# currently on node: (28, 33)
# currently on node: (28, 33)
# currently on node: (29, 37)
# currently on node: (38, 29)
# currently on node: (37, 30)
# currently on node: (37, 28)
# currently on node: (36, 29)
# currently on node: (29, 37)
# currently on node: (32, 36)
# currently on node: (37, 32)
# currently on node: (36, 33)
# currently on node: (32, 36)
# currently on node: (31, 32)
# currently on node: (31, 32)
# currently on node: (26, 38)
# currently on node: (39, 26)
# currently on node: (38, 27)
# currently on node: (38, 25)
# currently on node: (37, 26)
# currently on node: (26, 38)
# currently on node: (35, 35)
# currently on node: (35, 35)
# currently on node: (34, 31)
# currently on node: (34, 31)
# currently on node: (25, 21)
# currently on node: (26, 34)
# currently on node: (26, 34)
# currently on node: (29, 33)
# currently on node: (29, 33)
# currently on node: (30, 37)
# currently on node: (38, 30)
# currently on node: (37, 31)
# currently on node: (37, 29)
# currently on node: (36, 30)
# currently on node: (30, 37)
# currently on node: (33, 36)
# currently on node: (37, 33)
# currently on node: (36, 34)
# currently on node: (33, 36)
# currently on node: (27, 38)
# currently on node: (39, 27)
# currently on node: (38, 28)
# currently on node: (38, 26)
# currently on node: (37, 27)
# currently on node: (27, 38)
# currently on node: (32, 32)
# currently on node: (32, 32)
# currently on node: (36, 35)
# currently on node: (35, 31)
# currently on node: (35, 31)
# currently on node: (26, 21)
# currently on node: (23, 31)
# currently on node: (32, 23)
# currently on node: (31, 24)
# currently on node: (31, 22)
# currently on node: (30, 23)
# currently on node: (23, 31)
# currently on node: (22, 27)
# currently on node: (28, 22)
# currently on node: (27, 23)
# currently on node: (22, 27)
# currently on node: (27, 34)
# currently on node: (27, 34)
# currently on node: (24, 35)
# currently on node: (36, 24)
# currently on node: (35, 25)
# currently on node: (35, 23)
# currently on node: (34, 24)
# currently on node: (24, 35)
# currently on node: (30, 33)
# currently on node: (30, 33)
# currently on node: (31, 37)
# currently on node: (38, 31)
# currently on node: (37, 32)
# currently on node: (37, 30)
# currently on node: (31, 37)
# currently on node: (28, 38)
# currently on node: (39, 28)
# currently on node: (38, 29)
# currently on node: (38, 27)
# currently on node: (37, 28)
# currently on node: (28, 38)
# currently on node: (34, 36)
# currently on node: (37, 34)
# currently on node: (36, 35)
# currently on node: (34, 36)
# currently on node: (33, 32)
# currently on node: (33, 32)
# currently on node: (25, 39)
# currently on node: (40, 25)
# currently on node: (39, 26)
# currently on node: (39, 24)
# currently on node: (38, 25)
# currently on node: (24, 22)
# currently on node: (24, 22)
# currently on node: (36, 31)
# currently on node: (36, 31)
# currently on node: (27, 21)
# currently on node: (24, 31)
# currently on node: (24, 31)
# currently on node: (23, 27)
# currently on node: (23, 27)
# currently on node: (28, 34)
# currently on node: (28, 34)
# currently on node: (25, 35)
# currently on node: (25, 35)
# currently on node: (25, 35)
# currently on node: (32, 37)
# currently on node: (38, 32)
# currently on node: (37, 33)
# currently on node: (32, 37)
# currently on node: (31, 33)
# currently on node: (31, 33)
# currently on node: (29, 38)
# currently on node: (39, 29)
# currently on node: (38, 30)
# currently on node: (38, 28)
# currently on node: (37, 29)
# currently on node: (29, 38)
# currently on node: (35, 36)
# currently on node: (37, 35)
# currently on node: (35, 36)
# currently on node: (26, 39)
# currently on node: (40, 26)
# currently on node: (39, 27)
# currently on node: (39, 25)
# currently on node: (38, 26)
# currently on node: (26, 39)
# currently on node: (34, 32)
# currently on node: (34, 32)
# currently on node: (25, 22)
# currently on node: (37, 31)
# currently on node: (26, 35)
# currently on node: (26, 35)
# currently on node: (29, 34)
# currently on node: (29, 34)
# currently on node: (30, 38)
# currently on node: (39, 30)
# currently on node: (38, 31)
# currently on node: (38, 29)
# currently on node: (37, 30)
# currently on node: (30, 38)
# currently on node: (33, 37)
# currently on node: (38, 33)
# currently on node: (37, 34)
# currently on node: (33, 37)
# currently on node: (32, 33)
# currently on node: (32, 33)
# currently on node: (23, 23)
# currently on node: (23, 23)
# currently on node: (27, 39)
# currently on node: (40, 27)
# currently on node: (39, 28)
# currently on node: (39, 26)
# currently on node: (38, 27)
# currently on node: (27, 39)
# currently on node: (36, 36)
# currently on node: (36, 36)
# currently on node: (35, 32)
# currently on node: (35, 32)
# currently on node: (26, 22)
# currently on node: (22, 28)
# currently on node: (29, 22)
# currently on node: (28, 23)
# currently on node: (28, 21)
# currently on node: (22, 28)
# currently on node: (23, 32)
# currently on node: (33, 23)
# currently on node: (32, 24)
# currently on node: (32, 22)
# currently on node: (31, 23)
# currently on node: (23, 32)
# currently on node: (27, 35)
# currently on node: (27, 35)
# currently on node: (30, 34)
# currently on node: (30, 34)
# currently on node: (24, 36)
# currently on node: (37, 24)
# currently on node: (36, 25)
# currently on node: (36, 23)
# currently on node: (35, 24)
# currently on node: (24, 36)
# currently on node: (31, 38)
# currently on node: (39, 31)
# currently on node: (38, 32)
# currently on node: (38, 30)
# currently on node: (37, 31)
# currently on node: (31, 38)
# currently on node: (34, 37)
# currently on node: (38, 34)
# currently on node: (37, 35)
# currently on node: (34, 37)
# currently on node: (28, 39)
# currently on node: (40, 28)
# currently on node: (39, 29)
# currently on node: (39, 27)
# currently on node: (38, 28)
# currently on node: (28, 39)
# currently on node: (33, 33)
# currently on node: (33, 33)
# currently on node: (24, 23)
# currently on node: (37, 36)
# currently on node: (25, 40)
# currently on node: (41, 25)
# currently on node: (40, 26)
# currently on node: (40, 24)
# currently on node: (39, 25)
# currently on node: (36, 32)
# currently on node: (36, 32)
# currently on node: (27, 22)
# currently on node: (23, 28)
# currently on node: (23, 28)
# currently on node: (24, 32)
# currently on node: (24, 32)
# currently on node: (28, 35)
# currently on node: (28, 35)
# currently on node: (22, 24)
# currently on node: (25, 22)
# currently on node: (24, 23)
# currently on node: (22, 24)
# currently on node: (25, 36)
# currently on node: (25, 36)
# currently on node: (25, 36)
# currently on node: (31, 34)
# currently on node: (31, 34)
# currently on node: (32, 38)
# currently on node: (39, 32)
# currently on node: (38, 33)
# currently on node: (38, 31)
# currently on node: (32, 38)
# currently on node: (35, 37)
# currently on node: (38, 35)
# currently on node: (37, 36)
# currently on node: (35, 37)
# currently on node: (29, 39)
# currently on node: (40, 29)
# currently on node: (39, 30)
# currently on node: (39, 28)
# currently on node: (38, 29)
# currently on node: (29, 39)
# currently on node: (34, 33)
# currently on node: (34, 33)
# currently on node: (26, 40)
# currently on node: (41, 26)
# currently on node: (40, 27)
# currently on node: (40, 25)
# currently on node: (39, 26)
# currently on node: (26, 40)
# currently on node: (37, 32)
# currently on node: (37, 32)
# currently on node: (29, 35)
# currently on node: (29, 35)
# currently on node: (26, 36)
# currently on node: (26, 36)
# currently on node: (23, 24)
# currently on node: (23, 24)
# currently on node: (32, 34)
# currently on node: (32, 34)
# currently on node: (33, 38)
# currently on node: (39, 33)
# currently on node: (38, 34)
# currently on node: (33, 38)
# currently on node: (30, 39)
# currently on node: (40, 30)
# currently on node: (39, 31)
# currently on node: (39, 29)
# currently on node: (38, 30)
# currently on node: (30, 39)
# currently on node: (36, 37)
# currently on node: (38, 36)
# currently on node: (36, 37)
# currently on node: (27, 40)
# currently on node: (41, 27)
# currently on node: (40, 28)
# currently on node: (40, 26)
# currently on node: (39, 27)
# currently on node: (27, 40)
# currently on node: (35, 33)
# currently on node: (35, 33)
# currently on node: (38, 32)
# currently on node: (22, 29)
# currently on node: (30, 22)
# currently on node: (29, 23)
# currently on node: (29, 21)
# currently on node: (28, 22)
# currently on node: (22, 29)
# currently on node: (21, 25)
# currently on node: (26, 21)
# currently on node: (25, 22)
# currently on node: (23, 33)
# currently on node: (34, 23)
# currently on node: (33, 24)
# currently on node: (33, 22)
# currently on node: (32, 23)
# currently on node: (23, 33)
# currently on node: (27, 36)
# currently on node: (27, 36)
# currently on node: (30, 35)
# currently on node: (30, 35)
# currently on node: (24, 37)
# currently on node: (38, 24)
# currently on node: (37, 25)
# currently on node: (37, 23)
# currently on node: (36, 24)
# currently on node: (24, 37)
# currently on node: (34, 38)
# currently on node: (39, 34)
# currently on node: (38, 35)
# currently on node: (34, 38)
# currently on node: (31, 39)
# currently on node: (40, 31)
# currently on node: (39, 32)
# currently on node: (39, 30)
# currently on node: (38, 31)
# currently on node: (31, 39)
# currently on node: (33, 34)
# currently on node: (33, 34)
# currently on node: (37, 37)
# currently on node: (37, 37)
# currently on node: (28, 40)
# currently on node: (41, 28)
# currently on node: (40, 29)
# currently on node: (40, 27)
# currently on node: (39, 28)
# currently on node: (28, 40)
# currently on node: (36, 33)
# currently on node: (36, 33)
# currently on node: (25, 41)
# currently on node: (42, 25)
# currently on node: (41, 26)
# currently on node: (41, 24)
# currently on node: (40, 25)
# currently on node: (23, 29)
# currently on node: (23, 29)
# currently on node: (24, 33)
# currently on node: (24, 33)
# currently on node: (22, 25)
# currently on node: (22, 25)
# currently on node: (22, 25)
# currently on node: (28, 36)
# currently on node: (28, 36)
# currently on node: (31, 35)
# currently on node: (31, 35)
# currently on node: (25, 37)
# currently on node: (25, 37)
# currently on node: (25, 37)
# currently on node: (32, 39)
# currently on node: (40, 32)
# currently on node: (39, 33)
# currently on node: (39, 31)
# currently on node: (38, 32)
# currently on node: (32, 39)
# currently on node: (35, 38)
# currently on node: (39, 35)
# currently on node: (38, 36)
# currently on node: (35, 38)
# currently on node: (34, 34)
# currently on node: (34, 34)
# currently on node: (29, 40)
# currently on node: (41, 29)
# currently on node: (40, 30)
# currently on node: (40, 28)
# currently on node: (39, 29)
# currently on node: (29, 40)
# currently on node: (38, 37)
# currently on node: (26, 41)
# currently on node: (42, 26)
# currently on node: (41, 27)
# currently on node: (41, 25)
# currently on node: (40, 26)
# currently on node: (26, 41)
# currently on node: (37, 33)
# currently on node: (37, 33)
# currently on node: (29, 36)
# currently on node: (29, 36)
# currently on node: (26, 37)
# currently on node: (26, 37)
# currently on node: (32, 35)
# currently on node: (32, 35)
# currently on node: (33, 39)
# currently on node: (40, 33)
# currently on node: (39, 34)
# currently on node: (39, 32)
# currently on node: (33, 39)
# currently on node: (36, 38)
# currently on node: (39, 36)
# currently on node: (38, 37)
# currently on node: (36, 38)
# currently on node: (30, 40)
# currently on node: (41, 30)
# currently on node: (40, 31)
# currently on node: (40, 29)
# currently on node: (39, 30)
# currently on node: (30, 40)
# currently on node: (35, 34)
# currently on node: (35, 34)
# currently on node: (27, 41)
# currently on node: (42, 27)
# currently on node: (41, 28)
# currently on node: (41, 26)
# currently on node: (40, 27)
# currently on node: (27, 41)
# currently on node: (38, 33)
# currently on node: (38, 33)
# currently on node: (25, 20)
# currently on node: (22, 30)
# currently on node: (31, 22)
# currently on node: (30, 23)
# currently on node: (30, 21)
# currently on node: (29, 22)
# currently on node: (22, 30)
# currently on node: (21, 26)
# currently on node: (27, 21)
# currently on node: (26, 22)
# currently on node: (21, 26)
# currently on node: (23, 34)
# currently on node: (35, 23)
# currently on node: (34, 24)
# currently on node: (34, 22)
# currently on node: (33, 23)
# currently on node: (23, 34)
# currently on node: (30, 36)
# currently on node: (30, 36)
# currently on node: (27, 37)
# currently on node: (27, 37)
# currently on node: (33, 35)
# currently on node: (33, 35)
# currently on node: (34, 39)
# currently on node: (40, 34)
# currently on node: (39, 35)
# currently on node: (34, 39)
# currently on node: (31, 40)
# currently on node: (41, 31)
# currently on node: (40, 32)
# currently on node: (40, 30)
# currently on node: (39, 31)
# currently on node: (31, 40)
# currently on node: (24, 38)
# currently on node: (39, 24)
# currently on node: (38, 25)
# currently on node: (38, 23)
# currently on node: (37, 24)
# currently on node: (24, 38)
# currently on node: (37, 38)
# currently on node: (39, 37)
# currently on node: (37, 38)
# currently on node: (36, 34)
# currently on node: (36, 34)
# currently on node: (28, 41)
# currently on node: (42, 28)
# currently on node: (41, 29)
# currently on node: (41, 27)
# currently on node: (40, 28)
# currently on node: (28, 41)
# currently on node: (39, 33)
# currently on node: (25, 42)
# currently on node: (43, 25)
# currently on node: (42, 26)
# currently on node: (42, 24)
# currently on node: (41, 25)
# currently on node: (26, 20)
# currently on node: (23, 30)
# currently on node: (23, 30)
# currently on node: (22, 26)
# currently on node: (22, 26)
# currently on node: (24, 34)
# currently on node: (24, 34)
# currently on node: (31, 36)
# currently on node: (31, 36)
# currently on node: (28, 37)
# currently on node: (28, 37)
# currently on node: (34, 35)
# currently on node: (34, 35)
# currently on node: (35, 39)
# currently on node: (40, 35)
# currently on node: (39, 36)
# currently on node: (35, 39)
# currently on node: (25, 38)
# currently on node: (25, 38)
# currently on node: (25, 38)
# currently on node: (32, 40)
# currently on node: (41, 32)
# currently on node: (40, 33)
# currently on node: (40, 31)
# currently on node: (39, 32)
# currently on node: (32, 40)
# currently on node: (38, 38)
# currently on node: (38, 38)
# currently on node: (29, 41)
# currently on node: (42, 29)
# currently on node: (41, 30)
# currently on node: (41, 28)
# currently on node: (40, 29)
# currently on node: (29, 41)
# currently on node: (37, 34)
# currently on node: (37, 34)
# currently on node: (24, 21)
# currently on node: (24, 21)
# currently on node: (26, 42)
# currently on node: (43, 26)
# currently on node: (42, 27)
# currently on node: (42, 25)
# currently on node: (41, 26)
# currently on node: (26, 42)
# currently on node: (29, 37)
# currently on node: (29, 37)
# currently on node: (32, 36)
# currently on node: (32, 36)
# currently on node: (26, 38)
# currently on node: (26, 38)
# currently on node: (33, 40)
# currently on node: (41, 33)
# currently on node: (40, 34)
# currently on node: (40, 32)
# currently on node: (39, 33)
# currently on node: (33, 40)
# currently on node: (36, 39)
# currently on node: (40, 36)
# currently on node: (39, 37)
# currently on node: (36, 39)
# currently on node: (35, 35)
# currently on node: (35, 35)
# currently on node: (30, 41)
# currently on node: (42, 30)
# currently on node: (41, 31)
# currently on node: (41, 29)
# currently on node: (40, 30)
# currently on node: (30, 41)
# currently on node: (39, 38)
# currently on node: (38, 34)
# currently on node: (38, 34)
# currently on node: (27, 42)
# currently on node: (43, 27)
# currently on node: (42, 28)
# currently on node: (42, 26)
# currently on node: (41, 27)
# currently on node: (27, 42)
# currently on node: (25, 21)
# currently on node: (21, 27)
# currently on node: (28, 21)
# currently on node: (27, 22)
# currently on node: (27, 20)
# currently on node: (21, 27)
# currently on node: (22, 31)
# currently on node: (32, 22)
# currently on node: (31, 23)
# currently on node: (31, 21)
# currently on node: (30, 22)
# currently on node: (22, 31)
# currently on node: (23, 35)
# currently on node: (36, 23)
# currently on node: (35, 24)
# currently on node: (35, 22)
# currently on node: (34, 23)
# currently on node: (23, 35)
# currently on node: (30, 37)
# currently on node: (30, 37)
# currently on node: (33, 36)
# currently on node: (33, 36)
# currently on node: (27, 38)
# currently on node: (27, 38)
# currently on node: (34, 40)
# currently on node: (41, 34)
# currently on node: (40, 35)
# currently on node: (40, 33)
# currently on node: (34, 40)
# currently on node: (37, 39)
# currently on node: (40, 37)
# currently on node: (39, 38)
# currently on node: (37, 39)
# currently on node: (36, 35)
# currently on node: (36, 35)
# currently on node: (31, 41)
# currently on node: (42, 31)
# currently on node: (41, 32)
# currently on node: (41, 30)
# currently on node: (40, 31)
# currently on node: (31, 41)
# currently on node: (23, 22)
# currently on node: (23, 22)
# currently on node: (24, 39)
# currently on node: (40, 24)
# currently on node: (39, 25)
# currently on node: (39, 23)
# currently on node: (38, 24)
# currently on node: (24, 39)
# currently on node: (28, 42)
# currently on node: (43, 28)
# currently on node: (42, 29)
# currently on node: (42, 27)
# currently on node: (41, 28)
# currently on node: (28, 42)
# currently on node: (39, 34)
# currently on node: (39, 34)
# currently on node: (26, 21)
# currently on node: (25, 43)
# currently on node: (44, 25)
# currently on node: (43, 26)
# currently on node: (43, 24)
# currently on node: (42, 25)
# currently on node: (23, 31)
# currently on node: (23, 31)
# currently on node: (22, 27)
# currently on node: (22, 27)
# currently on node: (24, 35)
# currently on node: (24, 35)
# currently on node: (31, 37)
# currently on node: (31, 37)
# currently on node: (28, 38)
# currently on node: (28, 38)
# currently on node: (34, 36)
# currently on node: (34, 36)
# currently on node: (35, 40)
# currently on node: (41, 35)
# currently on node: (40, 36)
# currently on node: (35, 40)
# currently on node: (38, 39)
# currently on node: (40, 38)
# currently on node: (38, 39)
# currently on node: (32, 41)
# currently on node: (42, 32)
# currently on node: (41, 33)
# currently on node: (41, 31)
# currently on node: (40, 32)
# currently on node: (32, 41)
# currently on node: (25, 39)
# currently on node: (25, 39)
# currently on node: (25, 39)
# currently on node: (37, 35)
# currently on node: (37, 35)
# currently on node: (29, 42)
# currently on node: (43, 29)
# currently on node: (42, 30)
# currently on node: (42, 28)
# currently on node: (41, 29)
# currently on node: (29, 42)
# currently on node: (40, 34)
# currently on node: (26, 43)
# currently on node: (44, 26)
# currently on node: (43, 27)
# currently on node: (43, 25)
# currently on node: (42, 26)
# currently on node: (26, 43)
# currently on node: (32, 37)
# currently on node: (32, 37)
# currently on node: (22, 23)
# currently on node: (24, 22)
# currently on node: (22, 23)
# currently on node: (29, 38)
# currently on node: (29, 38)
# currently on node: (35, 36)
# currently on node: (35, 36)
# currently on node: (36, 40)
# currently on node: (41, 36)
# currently on node: (40, 37)
# currently on node: (36, 40)
# currently on node: (26, 39)
# currently on node: (26, 39)
# currently on node: (33, 41)
# currently on node: (42, 33)
# currently on node: (41, 34)
# currently on node: (41, 32)
# currently on node: (40, 33)
# currently on node: (33, 41)
# currently on node: (39, 39)
# currently on node: (39, 39)
# currently on node: (30, 42)
# currently on node: (43, 30)
# currently on node: (42, 31)
# currently on node: (42, 29)
# currently on node: (41, 30)
# currently on node: (30, 42)
# currently on node: (38, 35)
# currently on node: (38, 35)
# currently on node: (27, 43)
# currently on node: (44, 27)
# currently on node: (43, 28)
# currently on node: (43, 26)
# currently on node: (42, 27)
# currently on node: (27, 43)
# currently on node: (21, 28)
# currently on node: (29, 21)
# currently on node: (28, 22)
# currently on node: (28, 20)
# currently on node: (27, 21)
# currently on node: (21, 28)
# currently on node: (22, 32)
# currently on node: (33, 22)
# currently on node: (32, 23)
# currently on node: (32, 21)
# currently on node: (31, 22)
# currently on node: (22, 32)
# currently on node: (23, 36)
# currently on node: (37, 23)
# currently on node: (36, 24)
# currently on node: (36, 22)
# currently on node: (35, 23)
# currently on node: (23, 36)
# currently on node: (30, 38)
# currently on node: (30, 38)
# currently on node: (33, 37)
# currently on node: (33, 37)
# currently on node: (23, 23)
# currently on node: (23, 23)
# currently on node: (27, 39)
# currently on node: (27, 39)
# currently on node: (37, 40)
# currently on node: (41, 37)
# currently on node: (40, 38)
# currently on node: (37, 40)
# currently on node: (36, 36)
# currently on node: (36, 36)
# currently on node: (34, 41)
# currently on node: (42, 34)
# currently on node: (41, 35)
# currently on node: (41, 33)
# currently on node: (40, 34)
# currently on node: (34, 41)
# currently on node: (40, 39)
# currently on node: (31, 42)
# currently on node: (43, 31)
# currently on node: (42, 32)
# currently on node: (42, 30)
# currently on node: (41, 31)
# currently on node: (31, 42)
# currently on node: (24, 40)
# currently on node: (41, 24)
# currently on node: (40, 25)
# currently on node: (40, 23)
# currently on node: (39, 24)
# currently on node: (24, 40)
# currently on node: (39, 35)
# currently on node: (39, 35)
# currently on node: (28, 43)
# currently on node: (44, 28)
# currently on node: (43, 29)
# currently on node: (43, 27)
# currently on node: (42, 28)
# currently on node: (28, 43)
# currently on node: (25, 44)
# currently on node: (45, 25)
# currently on node: (44, 26)
# currently on node: (44, 24)
# currently on node: (43, 25)
# currently on node: (22, 28)
# currently on node: (22, 28)
# currently on node: (23, 32)
# currently on node: (23, 32)
# currently on node: (21, 24)
# currently on node: (25, 21)
# currently on node: (24, 22)
# currently on node: (21, 24)
# currently on node: (24, 36)
# currently on node: (24, 36)
# currently on node: (31, 38)
# currently on node: (31, 38)
# currently on node: (34, 37)
# currently on node: (34, 37)
# currently on node: (28, 39)
# currently on node: (28, 39)
# currently on node: (35, 41)
# currently on node: (42, 35)
# currently on node: (41, 36)
# currently on node: (41, 34)
# currently on node: (35, 41)
# currently on node: (38, 40)
# currently on node: (41, 38)
# currently on node: (40, 39)
# currently on node: (38, 40)
# currently on node: (37, 36)
# currently on node: (37, 36)
# currently on node: (32, 42)
# currently on node: (43, 32)
# currently on node: (42, 33)
# currently on node: (42, 31)
# currently on node: (41, 32)
# currently on node: (32, 42)
# currently on node: (25, 40)
# currently on node: (25, 40)
# currently on node: (25, 40)
# currently on node: (40, 35)
# currently on node: (40, 35)
# currently on node: (29, 43)
# currently on node: (44, 29)
# currently on node: (43, 30)
# currently on node: (43, 28)
# currently on node: (42, 29)
# currently on node: (29, 43)
# currently on node: (26, 44)
# currently on node: (45, 26)
# currently on node: (44, 27)
# currently on node: (44, 25)
# currently on node: (43, 26)
# currently on node: (26, 44)
# currently on node: (22, 24)
# currently on node: (22, 24)
# currently on node: (32, 38)
# currently on node: (32, 38)
# currently on node: (35, 37)
# currently on node: (35, 37)
# currently on node: (29, 39)
# currently on node: (29, 39)
# currently on node: (36, 41)
# currently on node: (42, 36)
# currently on node: (41, 37)
# currently on node: (36, 41)
# currently on node: (39, 40)
# currently on node: (41, 39)
# currently on node: (39, 40)
# currently on node: (33, 42)
# currently on node: (43, 33)
# currently on node: (42, 34)
# currently on node: (42, 32)
# currently on node: (41, 33)
# currently on node: (33, 42)
# currently on node: (38, 36)
# currently on node: (38, 36)
# currently on node: (26, 40)
# currently on node: (26, 40)
# currently on node: (30, 43)
# currently on node: (44, 30)
# currently on node: (43, 31)
# currently on node: (43, 29)
# currently on node: (42, 30)
# currently on node: (30, 43)
# currently on node: (41, 35)
# currently on node: (27, 44)
# currently on node: (45, 27)
# currently on node: (44, 28)
# currently on node: (44, 26)
# currently on node: (43, 27)
# currently on node: (27, 44)
# currently on node: (21, 29)
# currently on node: (30, 21)
# currently on node: (29, 22)
# currently on node: (29, 20)
# currently on node: (28, 21)
# currently on node: (21, 29)
# currently on node: (20, 25)
# currently on node: (26, 20)
# currently on node: (25, 21)
# currently on node: (22, 33)
# currently on node: (34, 22)
# currently on node: (33, 23)
# currently on node: (33, 21)
# currently on node: (32, 22)
# currently on node: (22, 33)
# currently on node: (33, 38)
# currently on node: (33, 38)
# currently on node: (23, 37)
# currently on node: (38, 23)
# currently on node: (37, 24)
# currently on node: (37, 22)
# currently on node: (36, 23)
# currently on node: (23, 37)
# currently on node: (30, 39)
# currently on node: (30, 39)
# currently on node: (36, 37)
# currently on node: (36, 37)
# currently on node: (37, 41)
# currently on node: (42, 37)
# currently on node: (41, 38)
# currently on node: (37, 41)
# currently on node: (34, 42)
# currently on node: (43, 34)
# currently on node: (42, 35)
# currently on node: (42, 33)
# currently on node: (41, 34)
# currently on node: (34, 42)
# currently on node: (40, 40)
# currently on node: (40, 40)
# currently on node: (27, 40)
# currently on node: (27, 40)
# currently on node: (39, 36)
# currently on node: (39, 36)
# currently on node: (31, 43)
# currently on node: (44, 31)
# currently on node: (43, 32)
# currently on node: (43, 30)
# currently on node: (42, 31)
# currently on node: (31, 43)
# currently on node: (24, 41)
# currently on node: (42, 24)
# currently on node: (41, 25)
# currently on node: (41, 23)
# currently on node: (40, 24)
# currently on node: (24, 41)
# currently on node: (28, 44)
# currently on node: (45, 28)
# currently on node: (44, 29)
# currently on node: (44, 27)
# currently on node: (43, 28)
# currently on node: (28, 44)
# currently on node: (25, 19)
# currently on node: (22, 29)
# currently on node: (22, 29)
# currently on node: (21, 25)
# currently on node: (21, 25)
# currently on node: (21, 25)
# currently on node: (23, 33)
# currently on node: (23, 33)
# currently on node: (25, 45)
# currently on node: (46, 25)
# currently on node: (45, 26)
# currently on node: (45, 24)
# currently on node: (44, 25)
# currently on node: (24, 37)
# currently on node: (24, 37)
# currently on node: (34, 38)
# currently on node: (34, 38)
# currently on node: (31, 39)
# currently on node: (31, 39)
# currently on node: (37, 37)
# currently on node: (37, 37)
# currently on node: (38, 41)
# currently on node: (42, 38)
# currently on node: (41, 39)
# currently on node: (38, 41)
# currently on node: (28, 40)
# currently on node: (28, 40)
# currently on node: (35, 42)
# currently on node: (43, 35)
# currently on node: (42, 36)
# currently on node: (42, 34)
# currently on node: (41, 35)
# currently on node: (35, 42)
# currently on node: (41, 40)
# currently on node: (32, 43)
# currently on node: (44, 32)
# currently on node: (43, 33)
# currently on node: (43, 31)
# currently on node: (42, 32)
# currently on node: (32, 43)
# currently on node: (40, 36)
# currently on node: (40, 36)
# currently on node: (25, 41)
# currently on node: (25, 41)
# currently on node: (25, 41)
# currently on node: (29, 44)
# currently on node: (45, 29)
# currently on node: (44, 30)
# currently on node: (44, 28)
# currently on node: (43, 29)
# currently on node: (29, 44)
# currently on node: (26, 45)
# currently on node: (46, 26)
# currently on node: (45, 27)
# currently on node: (45, 25)
# currently on node: (44, 26)
# currently on node: (26, 45)
# currently on node: (32, 39)
# currently on node: (32, 39)
# currently on node: (35, 38)
# currently on node: (35, 38)
# currently on node: (29, 40)
# currently on node: (29, 40)
# currently on node: (39, 41)
# currently on node: (42, 39)
# currently on node: (41, 40)
# currently on node: (39, 41)
# currently on node: (36, 42)
# currently on node: (43, 36)
# currently on node: (42, 37)
# currently on node: (42, 35)
# currently on node: (36, 42)
# currently on node: (38, 37)
# currently on node: (38, 37)
# currently on node: (33, 43)
# currently on node: (44, 33)
# currently on node: (43, 34)
# currently on node: (43, 32)
# currently on node: (42, 33)
# currently on node: (33, 43)
# currently on node: (26, 41)
# currently on node: (26, 41)
# currently on node: (41, 36)
# currently on node: (41, 36)
# currently on node: (30, 44)
# currently on node: (45, 30)
# currently on node: (44, 31)
# currently on node: (44, 29)
# currently on node: (43, 30)
# currently on node: (30, 44)
# currently on node: (24, 20)
# currently on node: (24, 20)
# currently on node: (20, 26)
# currently on node: (27, 20)
# currently on node: (26, 21)
# currently on node: (26, 19)
# currently on node: (20, 26)
# currently on node: (21, 30)
# currently on node: (31, 21)
# currently on node: (30, 22)
# currently on node: (30, 20)
# currently on node: (29, 21)
# currently on node: (21, 30)
# currently on node: (27, 45)
# currently on node: (46, 27)
# currently on node: (45, 28)
# currently on node: (45, 26)
# currently on node: (44, 27)
# currently on node: (27, 45)
# currently on node: (22, 34)
# currently on node: (35, 22)
# currently on node: (34, 23)
# currently on node: (34, 21)
# currently on node: (33, 22)
# currently on node: (22, 34)
# currently on node: (33, 39)
# currently on node: (33, 39)
# currently on node: (36, 38)
# currently on node: (36, 38)
# currently on node: (30, 40)
# currently on node: (30, 40)
# currently on node: (23, 38)
# currently on node: (39, 23)
# currently on node: (38, 24)
# currently on node: (38, 22)
# currently on node: (37, 23)
# currently on node: (23, 38)
# currently on node: (37, 42)
# currently on node: (43, 37)
# currently on node: (42, 38)
# currently on node: (37, 42)
# currently on node: (40, 41)
# currently on node: (42, 40)
# currently on node: (40, 41)
# currently on node: (39, 37)
# currently on node: (39, 37)
# currently on node: (34, 43)
# currently on node: (44, 34)
# currently on node: (43, 35)
# currently on node: (43, 33)
# currently on node: (42, 34)
# currently on node: (34, 43)
# currently on node: (27, 41)
# currently on node: (27, 41)
# currently on node: (31, 44)
# currently on node: (45, 31)
# currently on node: (44, 32)
# currently on node: (44, 30)
# currently on node: (43, 31)
# currently on node: (31, 44)
# currently on node: (42, 36)
# currently on node: (24, 42)
# currently on node: (43, 24)
# currently on node: (42, 25)
# currently on node: (42, 23)
# currently on node: (41, 24)
# currently on node: (24, 42)
# currently on node: (25, 20)
# currently on node: (28, 45)
# currently on node: (46, 28)
# currently on node: (45, 29)
# currently on node: (45, 27)
# currently on node: (44, 28)
# currently on node: (28, 45)
# currently on node: (22, 30)
# currently on node: (22, 30)
# currently on node: (21, 26)
# currently on node: (21, 26)
# currently on node: (23, 34)
# currently on node: (23, 34)
# currently on node: (34, 39)
# currently on node: (34, 39)
# currently on node: (25, 46)
# currently on node: (47, 25)
# currently on node: (46, 26)
# currently on node: (46, 24)
# currently on node: (45, 25)
# currently on node: (31, 40)
# currently on node: (31, 40)
# currently on node: (24, 38)
# currently on node: (24, 38)
# currently on node: (37, 38)
# currently on node: (37, 38)
# currently on node: (38, 42)
# currently on node: (43, 38)
# currently on node: (42, 39)
# currently on node: (38, 42)
# currently on node: (41, 41)
# currently on node: (41, 41)
# currently on node: (35, 43)
# currently on node: (44, 35)
# currently on node: (43, 36)
# currently on node: (43, 34)
# currently on node: (42, 35)
# currently on node: (35, 43)
# currently on node: (28, 41)
# currently on node: (28, 41)
# currently on node: (23, 21)
# currently on node: (23, 21)
# currently on node: (40, 37)
# currently on node: (40, 37)
# currently on node: (32, 44)
# currently on node: (45, 32)
# currently on node: (44, 33)
# currently on node: (44, 31)
# currently on node: (43, 32)
# currently on node: (32, 44)
# currently on node: (25, 42)
# currently on node: (25, 42)
# currently on node: (25, 42)
# currently on node: (29, 45)
# ...
# currently on node: (8, 101)
# currently on node: (10, 104)
# currently on node: (10, 104)
# currently on node: (9, 101)
# currently on node: (9, 101)
# currently on node: (7, 98)
# currently on node: (99, 7)
# currently on node: (98, 8)
# currently on node: (98, 6)
# currently on node: (97, 7)
# currently on node: (7, 98)
# currently on node: (8, 98)
# currently on node: (8, 98)
# currently on node: (6, 95)
# currently on node: (96, 6)
# currently on node: (95, 7)
# currently on node: (95, 5)
# currently on node: (94, 6)
# currently on node: (6, 95)
# currently on node: (7, 95)
# currently on node: (7, 95)
# currently on node: (6, 92)
# currently on node: (6, 92)
# currently on node: (12, 114)
# currently on node: (113, 12)
# currently on node: (11, 111)
# currently on node: (112, 11)
# currently on node: (111, 12)
# currently on node: (111, 10)
# currently on node: (110, 11)
# currently on node: (11, 111)
# currently on node: (10, 108)
# currently on node: (109, 10)
# currently on node: (108, 11)
# currently on node: (108, 9)
# currently on node: (107, 10)
# currently on node: (10, 108)
# currently on node: (12, 111)
# currently on node: (12, 111)
# currently on node: (9, 105)
# currently on node: (106, 9)
# currently on node: (105, 10)
# currently on node: (105, 8)
# currently on node: (104, 9)
# currently on node: (9, 105)
# currently on node: (11, 108)
# currently on node: (11, 108)
# currently on node: (8, 102)
# currently on node: (103, 8)
# currently on node: (102, 9)
# currently on node: (102, 7)
# currently on node: (101, 8)
# currently on node: (8, 102)
# currently on node: (10, 105)
# currently on node: (10, 105)
# currently on node: (7, 99)
# currently on node: (100, 7)
# currently on node: (99, 8)
# currently on node: (99, 6)
# currently on node: (98, 7)
# currently on node: (7, 99)
# currently on node: (9, 102)
# currently on node: (9, 102)
# currently on node: (8, 99)
# currently on node: (8, 99)
# currently on node: (6, 96)
# currently on node: (97, 6)
# currently on node: (96, 7)
# currently on node: (96, 5)
# currently on node: (95, 6)
# currently on node: (6, 96)
# currently on node: (7, 96)
# currently on node: (7, 96)
# currently on node: (6, 93)
# currently on node: (6, 93)
# currently on node: (11, 112)
# currently on node: (113, 11)
# currently on node: (112, 12)
# currently on node: (112, 10)
# currently on node: (111, 11)
# currently on node: (11, 112)
# currently on node: (10, 109)
# currently on node: (110, 10)
# currently on node: (109, 11)
# currently on node: (109, 9)
# currently on node: (108, 10)
# currently on node: (10, 109)
# currently on node: (9, 106)
# currently on node: (107, 9)
# currently on node: (106, 10)
# currently on node: (106, 8)
# currently on node: (105, 9)
# currently on node: (9, 106)
# currently on node: (12, 112)
# currently on node: (12, 112)
# currently on node: (11, 109)
# currently on node: (11, 109)
# currently on node: (8, 103)
# currently on node: (104, 8)
# currently on node: (103, 9)
# currently on node: (103, 7)
# currently on node: (102, 8)
# currently on node: (8, 103)
# currently on node: (10, 106)
# currently on node: (10, 106)
# currently on node: (7, 100)
# currently on node: (101, 7)
# currently on node: (100, 8)
# currently on node: (100, 6)
# currently on node: (99, 7)
# currently on node: (7, 100)
# currently on node: (9, 103)
# currently on node: (9, 103)
# currently on node: (8, 100)
# currently on node: (8, 100)
# currently on node: (6, 97)
# currently on node: (98, 6)
# currently on node: (97, 7)
# currently on node: (97, 5)
# currently on node: (96, 6)
# currently on node: (6, 97)
# currently on node: (7, 97)
# currently on node: (7, 97)
# currently on node: (6, 94)
# currently on node: (6, 94)
# currently on node: (11, 113)
# currently on node: (113, 12)
# currently on node: (113, 10)
# currently on node: (112, 11)
# currently on node: (11, 113)
# currently on node: (10, 110)
# currently on node: (111, 10)
# currently on node: (110, 11)
# currently on node: (110, 9)
# currently on node: (109, 10)
# currently on node: (10, 110)
# currently on node: (9, 107)
# currently on node: (108, 9)
# currently on node: (107, 10)
# currently on node: (107, 8)
# currently on node: (106, 9)
# currently on node: (9, 107)
# currently on node: (12, 113)
# currently on node: (11, 110)
# currently on node: (11, 110)
# currently on node: (8, 104)
# currently on node: (105, 8)
# currently on node: (104, 9)
# currently on node: (104, 7)
# currently on node: (103, 8)
# currently on node: (8, 104)
# currently on node: (10, 107)
# currently on node: (10, 107)
# currently on node: (7, 101)
# currently on node: (102, 7)
# currently on node: (101, 8)
# currently on node: (101, 6)
# currently on node: (100, 7)
# currently on node: (7, 101)
# currently on node: (9, 104)
# currently on node: (9, 104)
# currently on node: (8, 101)
# currently on node: (8, 101)
# currently on node: (6, 98)
# currently on node: (99, 6)
# currently on node: (98, 7)
# currently on node: (98, 5)
# currently on node: (97, 6)
# currently on node: (6, 98)
# currently on node: (7, 98)
# currently on node: (7, 98)
# currently on node: (6, 95)
# currently on node: (6, 95)
# currently on node: (11, 114)
# currently on node: (113, 11)
# currently on node: (10, 111)
# currently on node: (112, 10)
# currently on node: (111, 11)
# currently on node: (111, 9)
# currently on node: (110, 10)
# currently on node: (10, 111)
# currently on node: (9, 108)
# currently on node: (109, 9)
# currently on node: (108, 10)
# currently on node: (108, 8)
# currently on node: (107, 9)
# currently on node: (9, 108)
# currently on node: (11, 111)
# currently on node: (11, 111)
# currently on node: (8, 105)
# currently on node: (106, 8)
# currently on node: (105, 9)
# currently on node: (105, 7)
# currently on node: (104, 8)
# currently on node: (8, 105)
# currently on node: (10, 108)
# currently on node: (10, 108)
# currently on node: (7, 102)
# currently on node: (103, 7)
# currently on node: (102, 8)
# currently on node: (102, 6)
# currently on node: (101, 7)
# currently on node: (7, 102)
# currently on node: (9, 105)
# currently on node: (9, 105)
# currently on node: (6, 99)
# currently on node: (100, 6)
# currently on node: (99, 7)
# currently on node: (99, 5)
# currently on node: (98, 6)
# currently on node: (6, 99)
# currently on node: (8, 102)
# currently on node: (8, 102)
# currently on node: (7, 99)
# currently on node: (7, 99)
# currently on node: (6, 96)
# currently on node: (6, 96)
# currently on node: (10, 112)
# currently on node: (113, 10)
# currently on node: (112, 11)
# currently on node: (112, 9)
# currently on node: (111, 10)
# currently on node: (10, 112)
# currently on node: (9, 109)
# currently on node: (110, 9)
# currently on node: (109, 10)
# currently on node: (109, 8)
# currently on node: (108, 9)
# currently on node: (9, 109)
# currently on node: (8, 106)
# currently on node: (107, 8)
# currently on node: (106, 9)
# currently on node: (106, 7)
# currently on node: (105, 8)
# currently on node: (8, 106)
# currently on node: (11, 112)
# currently on node: (11, 112)
# currently on node: (10, 109)
# currently on node: (10, 109)
# currently on node: (7, 103)
# currently on node: (104, 7)
# currently on node: (103, 8)
# currently on node: (103, 6)
# currently on node: (102, 7)
# currently on node: (7, 103)
# currently on node: (9, 106)
# currently on node: (9, 106)
# currently on node: (6, 100)
# currently on node: (101, 6)
# currently on node: (100, 7)
# currently on node: (100, 5)
# currently on node: (99, 6)
# currently on node: (6, 100)
# currently on node: (8, 103)
# currently on node: (8, 103)
# currently on node: (7, 100)
# currently on node: (7, 100)
# currently on node: (6, 97)
# currently on node: (6, 97)
# currently on node: (10, 113)
# currently on node: (113, 11)
# currently on node: (113, 9)
# currently on node: (112, 10)
# currently on node: (10, 113)
# currently on node: (9, 110)
# currently on node: (111, 9)
# currently on node: (110, 10)
# currently on node: (110, 8)
# currently on node: (109, 9)
# currently on node: (9, 110)
# currently on node: (8, 107)
# currently on node: (108, 8)
# currently on node: (107, 9)
# currently on node: (107, 7)
# currently on node: (106, 8)
# currently on node: (8, 107)
# currently on node: (11, 113)
# currently on node: (10, 110)
# currently on node: (10, 110)
# currently on node: (7, 104)
# currently on node: (105, 7)
# currently on node: (104, 8)
# currently on node: (104, 6)
# currently on node: (103, 7)
# currently on node: (7, 104)
# currently on node: (9, 107)
# currently on node: (9, 107)
# currently on node: (6, 101)
# currently on node: (102, 6)
# currently on node: (101, 7)
# currently on node: (101, 5)
# currently on node: (100, 6)
# currently on node: (6, 101)
# currently on node: (8, 104)
# currently on node: (8, 104)
# currently on node: (7, 101)
# currently on node: (7, 101)
# currently on node: (6, 98)
# currently on node: (6, 98)
# currently on node: (10, 114)
# currently on node: (113, 10)
# currently on node: (9, 111)
# currently on node: (112, 9)
# currently on node: (111, 10)
# currently on node: (111, 8)
# currently on node: (110, 9)
# currently on node: (9, 111)
# currently on node: (8, 108)
# currently on node: (109, 8)
# currently on node: (108, 9)
# currently on node: (108, 7)
# currently on node: (107, 8)
# currently on node: (8, 108)
# currently on node: (7, 105)
# currently on node: (106, 7)
# currently on node: (105, 8)
# currently on node: (105, 6)
# currently on node: (104, 7)
# currently on node: (7, 105)
# currently on node: (10, 111)
# currently on node: (10, 111)
# currently on node: (9, 108)
# currently on node: (9, 108)
# currently on node: (6, 102)
# currently on node: (103, 6)
# currently on node: (102, 7)
# currently on node: (102, 5)
# currently on node: (101, 6)
# currently on node: (6, 102)
# currently on node: (8, 105)
# currently on node: (8, 105)
# currently on node: (7, 102)
# currently on node: (7, 102)
# currently on node: (6, 99)
# currently on node: (6, 99)
# currently on node: (9, 112)
# currently on node: (113, 9)
# currently on node: (112, 10)
# currently on node: (112, 8)
# currently on node: (111, 9)
# currently on node: (9, 112)
# currently on node: (8, 109)
# currently on node: (110, 8)
# currently on node: (109, 9)
# currently on node: (109, 7)
# currently on node: (108, 8)
# currently on node: (8, 109)
# currently on node: (7, 106)
# currently on node: (107, 7)
# currently on node: (106, 8)
# currently on node: (106, 6)
# currently on node: (105, 7)
# currently on node: (7, 106)
# currently on node: (10, 112)
# currently on node: (10, 112)
# currently on node: (9, 109)
# currently on node: (9, 109)
# currently on node: (6, 103)
# currently on node: (104, 6)
# currently on node: (103, 7)
# currently on node: (103, 5)
# currently on node: (102, 6)
# currently on node: (6, 103)
# currently on node: (8, 106)
# currently on node: (8, 106)
# currently on node: (7, 103)
# currently on node: (7, 103)
# currently on node: (6, 100)
# currently on node: (6, 100)
# currently on node: (9, 113)
# currently on node: (113, 10)
# currently on node: (113, 8)
# currently on node: (112, 9)
# currently on node: (9, 113)
# currently on node: (8, 110)
# currently on node: (111, 8)
# currently on node: (110, 9)
# currently on node: (110, 7)
# currently on node: (109, 8)
# currently on node: (8, 110)
# currently on node: (7, 107)
# currently on node: (108, 7)
# currently on node: (107, 8)
# currently on node: (107, 6)
# currently on node: (106, 7)
# currently on node: (7, 107)
# currently on node: (10, 113)
# currently on node: (9, 110)
# currently on node: (9, 110)
# currently on node: (6, 104)
# currently on node: (105, 6)
# currently on node: (104, 7)
# currently on node: (104, 5)
# currently on node: (103, 6)
# currently on node: (6, 104)
# currently on node: (8, 107)
# currently on node: (8, 107)
# currently on node: (7, 104)
# currently on node: (7, 104)
# currently on node: (6, 101)
# currently on node: (6, 101)
# currently on node: (9, 114)
# currently on node: (113, 9)
# currently on node: (8, 111)
# currently on node: (112, 8)
# currently on node: (111, 9)
# currently on node: (111, 7)
# currently on node: (110, 8)
# currently on node: (8, 111)
# currently on node: (7, 108)
# currently on node: (109, 7)
# currently on node: (108, 8)
# currently on node: (108, 6)
# currently on node: (107, 7)
# currently on node: (7, 108)
# currently on node: (6, 105)
# currently on node: (106, 6)
# currently on node: (105, 7)
# currently on node: (105, 5)
# currently on node: (104, 6)
# currently on node: (6, 105)
# currently on node: (9, 111)
# currently on node: (9, 111)
# currently on node: (8, 108)
# currently on node: (8, 108)
# currently on node: (7, 105)
# currently on node: (7, 105)
# currently on node: (6, 102)
# currently on node: (6, 102)
# currently on node: (8, 112)
# currently on node: (113, 8)
# currently on node: (112, 9)
# currently on node: (112, 7)
# currently on node: (111, 8)
# currently on node: (8, 112)
# currently on node: (7, 109)
# currently on node: (110, 7)
# currently on node: (109, 8)
# currently on node: (109, 6)
# currently on node: (108, 7)
# currently on node: (7, 109)
# currently on node: (6, 106)
# currently on node: (107, 6)
# currently on node: (106, 7)
# currently on node: (106, 5)
# currently on node: (105, 6)
# currently on node: (6, 106)
# currently on node: (9, 112)
# currently on node: (9, 112)
# currently on node: (8, 109)
# currently on node: (8, 109)
# currently on node: (7, 106)
# currently on node: (7, 106)
# currently on node: (6, 103)
# currently on node: (6, 103)
# currently on node: (8, 113)
# currently on node: (113, 9)
# currently on node: (113, 7)
# currently on node: (112, 8)
# currently on node: (8, 113)
# currently on node: (7, 110)
# currently on node: (111, 7)
# currently on node: (110, 8)
# currently on node: (110, 6)
# currently on node: (109, 7)
# currently on node: (7, 110)
# currently on node: (6, 107)
# currently on node: (108, 6)
# currently on node: (107, 7)
# currently on node: (107, 5)
# currently on node: (106, 6)
# currently on node: (6, 107)
# currently on node: (9, 113)
# currently on node: (8, 110)
# currently on node: (8, 110)
# currently on node: (7, 107)
# currently on node: (7, 107)
# currently on node: (6, 104)
# currently on node: (6, 104)
# currently on node: (8, 114)
# currently on node: (113, 8)
# currently on node: (7, 111)
# currently on node: (112, 7)
# currently on node: (111, 8)
# currently on node: (111, 6)
# currently on node: (110, 7)
# currently on node: (7, 111)
# currently on node: (6, 108)
# currently on node: (109, 6)
# currently on node: (108, 7)
# currently on node: (108, 5)
# currently on node: (107, 6)
# currently on node: (6, 108)
# currently on node: (8, 111)
# currently on node: (8, 111)
# currently on node: (7, 108)
# currently on node: (7, 108)
# currently on node: (6, 105)
# currently on node: (6, 105)
# currently on node: (7, 112)
# currently on node: (113, 7)
# currently on node: (112, 8)
# currently on node: (112, 6)
# currently on node: (111, 7)
# currently on node: (7, 112)
# currently on node: (6, 109)
# currently on node: (110, 6)
# currently on node: (109, 7)
# currently on node: (109, 5)
# currently on node: (108, 6)
# currently on node: (6, 109)
# currently on node: (8, 112)
# currently on node: (8, 112)
# currently on node: (7, 109)
# currently on node: (7, 109)
# currently on node: (6, 106)
# currently on node: (6, 106)
# currently on node: (7, 113)
# currently on node: (113, 8)
# currently on node: (113, 6)
# currently on node: (112, 7)
# currently on node: (7, 113)
# currently on node: (6, 110)
# currently on node: (111, 6)
# currently on node: (110, 7)
# currently on node: (110, 5)
# currently on node: (109, 6)
# currently on node: (6, 110)
# currently on node: (8, 113)
# currently on node: (7, 110)
# currently on node: (7, 110)
# currently on node: (6, 107)
# currently on node: (6, 107)
# currently on node: (7, 114)
# currently on node: (113, 7)
# currently on node: (6, 111)
# currently on node: (112, 6)
# currently on node: (111, 7)
# currently on node: (111, 5)
# currently on node: (110, 6)
# currently on node: (6, 111)
# currently on node: (7, 111)
# currently on node: (7, 111)
# currently on node: (6, 108)
# currently on node: (6, 108)
# currently on node: (6, 112)
# currently on node: (113, 6)
# currently on node: (112, 7)
# currently on node: (112, 5)
# currently on node: (111, 6)
# currently on node: (6, 112)
# currently on node: (7, 112)
# currently on node: (7, 112)
# currently on node: (6, 109)
# currently on node: (6, 109)
# currently on node: (6, 113)
# currently on node: (113, 7)
# currently on node: (113, 5)
# currently on node: (112, 6)
# currently on node: (6, 113)
# currently on node: (7, 113)
# currently on node: (6, 110)
# currently on node: (6, 110)
# currently on node: (6, 114)
# currently on node: (113, 6)
# currently on node: (6, 111)
# currently on node: (6, 111)
# currently on node: (6, 112)
# currently on node: (6, 112)
# currently on node: (6, 113)
# 'no way'

# %%
solve.show()

# %% [markdown]
# ### need to fix this bug:

# %%
solve2 = solve_maze_bfs('maze_images/hard_maze2.png', 35, 165, 1155, 1120)
solve2
# Out:
# rows 1200
# cols 1200
# found
# drawing path
# <PIL.Image.Image image mode=RGB size=1200x1200 at 0x7F8EDA59BD10>

# %% [markdown]
# ### Easy fix by cropping image

# %%
solve3 = solve_maze_bfs('maze_images/hard_maze2_cropped.png', 10, 130, 1125, 1070)
solve3
# Out:
# rows 1128
# cols 1131
# found
# drawing path
# <PIL.Image.Image image mode=RGB size=1131x1128 at 0x7F8EDA151F50>

# %%
solve2.show()

# %%
circle = solve_maze_bfs('maze_images/circle_maze.png',145,3,145,90)
circle
# Out:
# rows 178
# cols 283
# found
# drawing path
# <PIL.Image.Image image mode=RGB size=283x178 at 0x7F8F110F6E10>
